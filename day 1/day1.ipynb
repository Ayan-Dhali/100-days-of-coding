# %% [markdown]
# # Day 1 of 100 days journey
# ### ***Day 1 project: Brand name generator***
#
# ***What i will learn***
# -printing,inputing,commenting,debugging,name errors,syntax errors,string manipulation,variables

# %% [markdown]
# ## Why to program?
# **Ans-** To tell the computer what to do

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# A simple first code to print what you want

# %% [markdown]
# inside th print **hello world is a string and "" show from where it start to where it end**

# %% [markdown]
# Now for coding you will get more errors like
# ***SyntaxError: ...***
# If you get this dont panic **just copy the error and paste it to google or any ai** it will tell you the solution

# %% [markdown]
# Now to go another line in print we use
# #### \n

# %%
print("hello \n world")
# Out:
# hello
#  world

# %% [markdown]
# we can also concatenate strings

# %%
print("hello"+" "+"world")
# Out:
# hello world

# %% [markdown]
# ### NOW ONE THING ALWAYS TO REMEMBER IS SPACES ARE VERY IMPORTANT IN PYTHON

# %% [markdown]
#  python("hello")
#
#  ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 python("hello")
#
# NameError: name 'python' is not defined

# %% [markdown]
# Now to take input from user we use **input function**

# %%
name=input("input your name")
print(name)
# Out:
# ayan

# %% [markdown]
# So in above we use `name` this is a variable. You can thik it like a container which can store data

# %% [markdown]
# # ALWAYS REMEMBER THAT USING GOOGLE IS ONE OF THE MOST USEFUL THING SINCE YOU CAN NEVER REMEMBER EVERYTHING

# %% [markdown]
# ## **Always try to name the variables good instead just random variables because when you come maybe after 3-4 months you cant remember those random variables so you need to look every code to know
