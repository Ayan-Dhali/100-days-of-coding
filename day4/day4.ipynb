# %% [markdown]
# <h1 style="text-align:center">Randomisation</h1>

# %% [markdown]
# Ok so in life we need many time randomization like playing rock,paper scissors etc.
#
# So to get this randomization we use random module

# %%
import random

# %% [markdown]
# That's how you import a module in python. and by this you import random module

# %%
# to get random number among the range
# random.randint(start,stop) range will be start to stop+1

print(random.randint(1,100))
# Out:
# 54

# %% [markdown]
# ## So what is a module?
# ##### ***so when you are workng on a big project the code will get bigger and bigger and eventually it will be hard to understand so what we do that devide its different functionality in different files. Each of tjis file called a different module***

# %% [markdown]
# ***So here the random module is a module created by some developer which help us to randomization.***

# %% [markdown]
# **So now can you create your own module?**
# *Answer is yes* you just need to create different file then import it as its shown below example

# %%
import example
print(example.exampe_num)
# Out:
# 3.1415

# %% [markdown]
# Now how to know what inside the module.
# ***We use help() function for it***

# %%
help(example)
# Out:
# Help on module example:
#
# NAME
#     example
#
# DATA
#     exampe_num = 3.1415
#
# FILE
#     c:\users\ayan dhali\onedrive\desktop\100 days of coding\day4\example.py

# %%
# To get between 0 to 1 we use random.random()
# To get float number from a certain range we use random.uniform(a,b)

# %% [markdown]
# ***Now if you want to randomize between specific strings... you can use list***
# For a quick revision lis is a data structure which can store multiple items in a single variable.

# %% [markdown]
# To get random among choice we can use random.choice(list)/choices for multiple
# or we can do like x=random.randint(0,list_length)
# list[x]

# %%
dice=[1,2,3,4,5,6]
print(random.choice(dice))
print(random.choices(dice,k=2))
# Out:
# 5
# [1, 4]
